# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Visualization settings
plt.style.use('seaborn-v0_8')
sns.set_palette("Set2")

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ### Load datasets

# %%
application_df = pd.read_csv('/content/application_data.csv')
previous_df = pd.read_csv('/content/columns_description.csv')
columns_desc = pd.read_csv('/content/columns_description.csv')

# import zipfile
# import os
# from google.colab import files

# # 1. Upload the zip file
# print("Please upload your zip file:")
# uploaded = files.upload()

# # 2. Unzip the file
# for filename in uploaded.keys():
#     # Define where you want to extract the files
#     extract_path = './dataset_extracted'

#     # Create the directory if it doesn't exist
#     if not os.path.exists(extract_path):
#         os.makedirs(extract_path)

#     # Perform the extraction
#     with zipfile.ZipFile(filename, 'r') as zip_ref:
#         zip_ref.extractall(extract_path)

#     print(f"\nSuccessfully unzipped '{filename}' to '{extract_path}'")

#     # Optional: List files to verify
#     print("Files found:", os.listdir(extract_path))

# %% [markdown]
# ### Initial data overview

# %%
print("Application Data Shape:", application_df.shape)
print("Previous Application Data Shape:", previous_df.shape)
print("Columns Description Shape:", columns_desc.shape)
# Out:
# Application Data Shape: (11631, 122)
# Previous Application Data Shape: (160, 5)
# Columns Description Shape: (160, 5)

# %% [markdown]
# Preview application data

# %%
application_df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0         202500.00   406597.50     24700.50
# 1               N             0         270000.00  1293502.50     35698.50
# 2               Y             0          67500.00   135000.00      6750.00
# 3               Y             0         135000.00   312682.50     29686.50
# 4               Y             0         121500.00   513000.00     21865.50
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0        351000.00   Unaccompanied          Working
# ...

# %% [markdown]
# ### Understand the target variable

# %%
application_df['TARGET'].value_counts(normalize=True) * 100
# Out:
# TARGET
# 0   92.28
# 1    7.72
# Name: proportion, dtype: float64

# %% [markdown]
# ### visual target imbalance

# %%
sns.countplot(x='TARGET', data=application_df)
plt.title("Target Variable Distribution (0 = No Default, 1 = Default)")
plt.show()

# %% [markdown]
# ### Missing value analysis

# %%
missing_df = application_df.isnull().mean().sort_values(ascending=False)
missing_df = missing_df[missing_df > 0]

missing_df.head(10)
# Out:
# COMMONAREA_AVG             0.70
# COMMONAREA_MODE            0.70
# COMMONAREA_MEDI            0.70
# NONLIVINGAPARTMENTS_MEDI   0.69
# NONLIVINGAPARTMENTS_MODE   0.69
# NONLIVINGAPARTMENTS_AVG    0.69
# FONDKAPREMONT_MODE         0.69
# LIVINGAPARTMENTS_AVG       0.68
# LIVINGAPARTMENTS_MEDI      0.68
# LIVINGAPARTMENTS_MODE      0.68
# dtype: float64

# %% [markdown]
# ### Plot missing value percentage (Top 20)

# %%
plt.figure(figsize=(10,6))
missing_df.head(20).plot(kind='bar')
plt.title("Top 20 Columns with Missing Values")
plt.ylabel("Missing Percentage")
plt.show()

# %%
application_df.describe()
# Out:
#        SK_ID_CURR   TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# count    11631.00 11631.00      11631.00          11631.00    11631.00
# mean    106779.58     0.08          0.42         167872.00   600094.66
# std       3906.50     0.27          0.72          96490.99   402680.18
# min     100002.00     0.00          0.00          25650.00    45000.00
# 25%     103389.50     0.00          0.00         112500.00   270000.00
# 50%     106799.00     0.00          0.00         144000.00   512446.50
# 75%     110151.50     0.00          1.00         202500.00   810000.00
# max     113548.00     1.00          7.00        2250000.00  2961000.00
#
#        AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# count     11631.00         11622.00                    11630.00    11630.00
# mean      27103.47        539877.53                        0.02   -16006.47
# std       14388.02        370464.64                        0.01     4345.48
# ...

# %%
previous_df.describe()
# Out:
#        Unnamed: 0
# count      160.00
# mean        94.59
# std         64.13
# min          1.00
# 25%         42.75
# 50%         82.50
# 75%        122.25
# max        213.00

# %%
columns_desc.describe()
# Out:
#        Unnamed: 0
# count      160.00
# mean        94.59
# std         64.13
# min          1.00
# 25%         42.75
# 50%         82.50
# 75%        122.25
# max        213.00

# %% [markdown]
# ### Age distribution analysis
#
# Age is a key risk indicator.

# %%
application_df['AGE_YEARS'] = abs(application_df['DAYS_BIRTH']) / 365

plt.figure(figsize=(8,5))
sns.histplot(application_df['AGE_YEARS'], bins=30, kde=True)
plt.title("Applicant Age Distribution")
plt.xlabel("Age (Years)")
plt.show()

# %% [markdown]
# ### Age vs Default

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='TARGET', y='AGE_YEARS', data=application_df)
plt.title("Age vs Default")
plt.show()

# %% [markdown]
# ### Income distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(application_df['AMT_INCOME_TOTAL'], bins=50)
plt.xlim(0, 500000)
plt.title("Applicant Income Distribution")
plt.show()

# %% [markdown]
# ### Check whether low income correlates with default.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='TARGET', y='AMT_INCOME_TOTAL', data=application_df)
plt.ylim(0, 500000)
plt.title("Income vs Default")
plt.show()

# %% [markdown]
# ### Credit source features vs Default

# %%
ext_features = ['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']

plt.figure(figsize=(12,4))
for i, col in enumerate(ext_features, 1):
    plt.subplot(1,3,i)
    sns.boxplot(x='TARGET', y=col, data=application_df)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan amount analysis

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='TARGET', y='AMT_CREDIT', data=application_df)
plt.ylim(0, 2000000)
plt.title("Loan Amount vs Default")
plt.show()

# %% [markdown]
# ### Correlation heatmap

# %%
corr_features = [
    'TARGET',
    'AMT_INCOME_TOTAL',
    'AMT_CREDIT',
    'AMT_ANNUITY',
    'AGE_YEARS',
    'EXT_SOURCE_1',
    'EXT_SOURCE_2',
    'EXT_SOURCE_3'
]

corr = application_df[corr_features].corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # EDA → modeling pipeline

# %% [markdown]
# ### Target & basic sanity checks

# %%
# Target distribution
application_df['TARGET'].value_counts(normalize=True)
# Out:
# TARGET
# 0   0.92
# 1   0.08
# Name: proportion, dtype: float64

# %% [markdown]
# ### Drop ID & extremely sparse columns

# %%
# Drop ID column
application_df = application_df.drop(columns=['SK_ID_CURR'])

# Drop columns with >70% missing
missing_ratio = application_df.isnull().mean()
high_missing_cols = missing_ratio[missing_ratio > 0.70].index.tolist()

application_df = application_df.drop(columns=high_missing_cols)

print(f"Dropped {len(high_missing_cols)} high-missing columns")
print(application_df.shape)
# Out:
# Dropped 0 high-missing columns
# (11631, 122)

# %% [markdown]
# ### Create meaningful features

# %%
# Age in years
application_df['AGE_YEARS'] = (-application_df['DAYS_BIRTH']) / 365

# Employment stability
application_df['EMPLOYMENT_YEARS'] = (-application_df['DAYS_EMPLOYED']) / 365
application_df.loc[application_df['EMPLOYMENT_YEARS'] < 0, 'EMPLOYMENT_YEARS'] = np.nan

# Income to credit ratio
application_df['INCOME_CREDIT_RATIO'] = (
    application_df['AMT_INCOME_TOTAL'] / application_df['AMT_CREDIT']
)

# Missing EXT_SOURCE indicator
application_df['MISSING_EXT_SOURCE'] = (
    application_df[['EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3']]
    .isnull()
    .any(axis=1)
    .astype(int)
)

# %% [markdown]
# ### Separate numerical & categorical columns

# %%
target = application_df['TARGET']
features = application_df.drop(columns=['TARGET'])

num_cols = features.select_dtypes(include=['int64','float64']).columns
cat_cols = features.select_dtypes(include=['object']).columns

print("Numerical:", len(num_cols))
print("Categorical:", len(cat_cols))
# Out:
# Numerical: 108
# Categorical: 16

# %% [markdown]
# ### Handle missing values

# %%
from sklearn.impute import SimpleImputer

# Numerical → median
num_imputer = SimpleImputer(strategy='median')
features[num_cols] = num_imputer.fit_transform(features[num_cols])

# Categorical → most frequent
cat_imputer = SimpleImputer(strategy='most_frequent')
features[cat_cols] = cat_imputer.fit_transform(features[cat_cols])

# %% [markdown]
# ### Encode categorical variables

# %%
features = pd.get_dummies(
    features,
    columns=cat_cols,
    drop_first=True
)

print(features.shape)
# Out:
# (11631, 229)

# %% [markdown]
# ### spliting the data in to train and test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features,
    target,
    test_size=0.2,
    random_state=42,
    stratify=target
)

print(X_train.shape, X_test.shape)
# Out:
# (9304, 229) (2327, 229)

# %% [markdown]
# ### Train LightGBM

# %%
import lightgbm as lgb

# %%
import re

# Clean column names for LightGBM compatibility
def clean_col_names(df):
    cols = df.columns
    new_cols = []
    for col in cols:
        new_col = re.sub(r'[^A-Za-z0-9_]+', '', col) # Remove special characters
        new_cols.append(new_col)
    df.columns = new_cols
    return df

X_train = clean_col_names(X_train)
X_test = clean_col_names(X_test)

model = lgb.LGBMClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=-1,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 718, number of negative: 8586
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10901
# [LightGBM] [Info] Number of data points in the train set: 9304, number of used features: 192
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.8,
#                learning_rate=0.05, n_estimators=300, random_state=42,
#                subsample=0.8)

# %% [markdown]
# ### Model evaluation

# %%
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:,1]

print("ROC-AUC:", roc_auc_score(y_test, y_proba))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# ROC-AUC: 0.7309061739895462
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      2147
#            1       0.28      0.32      0.30       180
#
#     accuracy                           0.88      2327
#    macro avg       0.61      0.63      0.62      2327
# weighted avg       0.89      0.88      0.89      2327

# %% [markdown]
# ### Confusion matrix (business view)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### Feature importance

# %%
importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=False)

importance.head(15)
# Out:
#                         Feature  Importance
# 28                 EXT_SOURCE_2         488
# 29                 EXT_SOURCE_3         459
# 8             DAYS_REGISTRATION         451
# 9               DAYS_ID_PUBLISH         449
# 3                   AMT_ANNUITY         410
# 77       DAYS_LAST_PHONE_CHANGE         392
# 5    REGION_POPULATION_RELATIVE         321
# 27                 EXT_SOURCE_1         295
# 106         INCOME_CREDIT_RATIO         285
# 1              AMT_INCOME_TOTAL         282
# 6                    DAYS_BIRTH         246
# 105            EMPLOYMENT_YEARS         246
# 7                 DAYS_EMPLOYED         239
# 2                    AMT_CREDIT         237
# 4               AMT_GOODS_PRICE         214

# %%
plt.figure(figsize=(8,6))
sns.barplot(
    data=importance.head(15),
    x='Importance',
    y='Feature'
)
plt.title("Top 15 Important Features")
plt.show()

# %% [markdown]
# ### Optimize decision threshold

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

plt.figure(figsize=(6,4))
plt.plot(thresholds, precision[:-1], label='Precision')
plt.plot(thresholds, recall[:-1], label='Recall')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.legend()
plt.title('Precision-Recall vs Threshold')
plt.show()

# %% [markdown]
# ### Create risk bands

# %%
def risk_band(prob):
    if prob < 0.25:
        return 'Low Risk'
    elif prob < 0.50:
        return 'Medium Risk'
    else:
        return 'High Risk'

risk_labels = pd.Series(y_proba).apply(risk_band)
risk_labels.value_counts()
# Out:
# Low Risk       1741
# Medium Risk     382
# High Risk       204
# Name: count, dtype: int64

# %%
import joblib

joblib.dump(model, 'loan_risk_model.pkl')
joblib.dump(num_imputer, 'num_imputer.pkl')
joblib.dump(cat_imputer, 'cat_imputer.pkl')
# Out:
# ['cat_imputer.pkl']

# %%
import joblib
import numpy as np

# Load saved objects
loaded_model = joblib.load('loan_risk_model.pkl')
num_imp = joblib.load('num_imputer.pkl')
cat_imp = joblib.load('cat_imputer.pkl')

# Test on one sample
sample = X_test.iloc[[0]]
pred_prob = loaded_model.predict_proba(sample)[0][1]

pred_prob
# Out:
# np.float64(0.28237224588138493)

# %%
def preprocess_input(df):
    df = df.copy()

    # Feature engineering
    df['AGE_YEARS'] = (-df['DAYS_BIRTH']) / 365
    df['EMPLOYMENT_YEARS'] = (-df['DAYS_EMPLOYED']) / 365
    df.loc[df['EMPLOYMENT_YEARS'] < 0, 'EMPLOYMENT_YEARS'] = np.nan

    df['INCOME_CREDIT_RATIO'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']

    df['MISSING_EXT_SOURCE'] = (
        df[['EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3']]
        .isnull()
        .any(axis=1)
        .astype(int)
    )

    # Drop unused columns
    df = df.drop(columns=['SK_ID_CURR'], errors='ignore')

    # Impute
    df[num_cols] = num_imp.transform(df[num_cols])
    df[cat_cols] = cat_imp.transform(df[cat_cols])

    # Encode
    df = pd.get_dummies(df)
    df = df.reindex(columns=X_train.columns, fill_value=0)

    return df

# %%
def loan_decision(prob):
    if prob < 0.25:
        return "Approved – Low Risk"
    elif prob < 0.50:
        return "Approved – Medium Risk (Higher Interest)"
    else:
        return "Rejected – High Risk"
